# %%
# %load_ext sql
# %sql sqlite:///store.db

# %%
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %% [markdown]
# ## Задание 1
# Для каждого артиста вывести все жанры, которые есть в его песнях, и для каждого жанра вывести наиболее продолжительную песню этого артиста.

# %%
# %%sql
# WITH RankedTracks AS (
#     SELECT
#         a.Name AS Artist,
#         g.Name AS Genre,
#         t.Name AS Track,
#         t.Milliseconds,
#         ROW_NUMBER() OVER (PARTITION BY a.ArtistId, g.GenreId ORDER BY t.Milliseconds DESC) AS rn
#     FROM artists a
#     JOIN albums al ON a.ArtistId = al.ArtistId
#     JOIN tracks t ON al.AlbumId = t.AlbumId
#     JOIN genres g ON t.GenreId = g.GenreId
#     WHERE g.Name IS NOT NULL
# )
#
# SELECT
#     Artist,
#     Genre,
#     Track AS LongestTrack,
#     Milliseconds AS Duration
# FROM RankedTracks
# WHERE rn = 1
# ORDER BY Artist, Genre;
# Out:
#  * sqlite:///store.db
# Done.
# [('AC/DC', 'Rock', 'Overdose', 369319),
#  ('Aaron Copland & London Symphony Orchestra', 'Classical', 'Fanfare for the Common Man', 198064),
#  ('Aaron Goldberg', 'Jazz', "OAM's Blues", 266936),
#  ('Academy of St. Martin in the Fields & Sir Neville Marriner', 'Classical', 'Fantasia On Greensleeves', 268066),
#  ('Academy of St. Martin in the Fields Chamber Ensemble & Sir Neville Marriner', 'Classical', '"Eine Kleine Nachtmusik" Serenade In G, K. 525: I. Allegro', 348971),
#  ('Academy of St. Martin in the Fields, John Birch, Sir Neville Marriner & Sylvia McNair', 'Classical', 'Requiem, Op.48: 4. Pie Jesu', 258924),
#  ('Academy of St. Martin in the Fields, Sir Neville Marriner & Thurston Dart', 'Classical', 'Suite No. 3 in D, BWV 1068: III. Gavotte I & II', 225933),
#  ('Accept', 'Rock', 'Princess of the Dawn', 375418),
#  ('Adrian Leaper & Doreen de Feis', 'Classical', 'Symphony No. 3 Op. 36 for Orchestra and Soprano "Symfonia Piesni Zalosnych" \\ Lento E Largo - Tranquillissimo', 567494),
#  ('Aerosmith', 'Rock', "Livin' On The Edge", 381231),
#  ('Aisha Duo', 'Jazz', 'Despertar', 307385),
#  ('Alanis Morissette', 'Rock', 'You Oughta Know (Alternate)', 491885),
#  ('Alberto Turco & Nova Schola Gregoriana', 'Classical', 'Intoitus: Adorate Deum', 245317),
#  ('Alice In Chains', 'Rock', 'Love, Hate, Love', 387134),
#  ('Amy Winehouse', 'Pop', 'Amy Amy Amy (Outro)', 663426),
#  ('Amy Winehouse', 'R&B/Soul', 'Rehab (Hot Chip Remix)', 418293),
#  ('Anne-Sophie Mutter, Herbert Von Karajan & Wiener Philharmoniker', 'Classical', 'Concerto No. 1 in E Major, RV 269 "Spring": I. Allegro', 199086),
#  ('Antal Doráti & London Symphony Orchestra', 'Classical', "Wellington's Victory or the Battle Symphony, Op.91: 2. Symphony of Triumph", 412000),
#  ('Antônio Carlos Jobim', 'Jazz', 'O Boto (Bôto)', 366837),
#  ('Antônio Carlos Jobim', 'Latin', 'Só Tinha De Ser Com Você', 389642),
#  ('Apocalyptica', 'Metal', 'Master Of Puppets', 436453),
#  ('Aquaman', 'TV Shows', 'Pilot', 2484567),
#  ('Audioslave', 'Alternative', 'Show Me How to Live (Live at the Quart Festival)', 301974),
#  ('Audioslave', 'Alternative & Punk', 'The Curse', 309786),
#  ('Audioslave', 'Rock', 'Shadow on the Sun', 343457),
#  ('BackBeat', 'Rock And Roll', 'Slow Down', 163265),
#  ('Barry Wordsworth & BBC Concert Orchestra', 'Classical', 'Nimrod (Adagio) from Variations On an Original Theme, Op. 36 "Enigma"', 250031),
#  ('Battlestar Galactica', 'Sci Fi & Fantasy', 'Crossroads, Pt. 2', 2869953),
#  ('Battlestar Galactica', 'Science Fiction', 'Hero', 2713755),
#  ('Battlestar Galactica', 'TV Shows', 'Occupation / Precipice', 5286953),
#  ('Battlestar Galactica (Classic)', 'Sci Fi & Fantasy', 'Greetings from Earth, Pt. 1', 2960293),
#  ('Berliner Philharmoniker & Hans Rosbaud', 'Classical', 'Karelia Suite, Op.11: 2. Ballade (Tempo Di Menuetto)', 406000),
#  ('Berliner Philharmoniker & Herbert Von Karajan', 'Classical', 'Symphony No. 41 in C Major, K. 551, "Jupiter": IV. Molto allegro', 362933),
#  ('Berliner Philharmoniker, Claudio Abbado & Sabine Meyer', 'Classical', 'Concerto for Clarinet in A Major, K. 622: II. Adagio', 394482),
#  ('Billy Cobham', 'Jazz', 'Stratus', 582086),
#  ('Black Label Society', 'Metal', 'No More Tears', 555075),
#  ('Black Sabbath', 'Metal', 'Sleeping Village', 644571),
#  ('Body Count', 'Alternative & Punk', 'The Winner Loses', 392254),
#  ('Boston Symphony Orchestra & Seiji Ozawa', 'Classical', 'Carmina Burana: O Fortuna', 156710),
#  ('Britten Sinfonia, Ivor Bolton & Lesley Garrett', 'Classical', 'Ave Maria', 338243),
#  ('Bruce Dickinson', 'Metal', 'The Alchemist', 509413),
#  ('Buddy Guy', 'Blues', "Talkin' 'Bout Women Obviously", 589531),
#  ('C. Monteverdi, Nigel Rogers - Chiaroscuro; London Baroque; London Cornett & Sackbu', 'Classical', "L'orfeo, Act 3, Sinfonia (Orchestra)", 66639),
#  ('Caetano Veloso', 'Latin', 'Terra', 482429),
#  ('Cake', 'Alternative', 'War Pigs', 234013),
#  ('Calexico', 'Alternative', 'Slowness', 215386),
#  ("Charles Dutoit & L'Orchestre Symphonique de Montréal", 'Classical', '3 Gymnopédies: No.1 - Lent Et Grave, No.3 - Lent Et Douloureux', 385506),
#  ('Chicago Symphony Chorus, Chicago Symphony Orchestra & Sir Georg Solti', 'Classical', 'Nabucco: Chorus, "Va, Pensiero, Sull\'ali Dorate"', 274504),
#  ('Chicago Symphony Orchestra & Fritz Reiner', 'Classical', "Scheherazade, Op. 35: I. The Sea and Sindbad's Ship", 545203),
#  ('Chico Buarque', 'Latin', 'Voce Nao Entende Nada - Cotidiano', 421982),
#  ('Chico Science & Nação Zumbi', 'Latin', 'Computadores Fazem Arte', 404323),
#  ('Choir Of Westminster Abbey & Simon Preston', 'Classical', 'Missa Papae Marcelli: Kyrie', 240666),
#  ('Chor der Wiener Staatsoper, Herbert Von Karajan & Wiener Philharmoniker', 'Classical', 'Carmen: Overture', 132932),
#  ('Chris Cornell', 'Alternative', 'Billie Jean', 281401),
#  ("Christopher O'Riley", 'Classical', 'SCRIABIN: Prelude in B Major, Op. 11, No. 11', 101293),
#  ('Cidade Negra', 'Reggae', 'Extra', 304352),
#  ('Cláudio Zoli', 'Latin', 'Noite Do Prazer', 311353),
#  ('Creedence Clearwater Revival', 'Rock', 'I Heard It Through The Grapevine', 664894),
#  ('Cássia Eller', 'Latin', 'Smells Like Teen Spirit (Ao Vivo)', 316865),
#  ('David Coverdale', 'Rock', 'River Song', 439510),
#  ('Deep Purple', 'Rock', "Space Truckin'", 1196094),
#  ('Def Leppard', 'Rock', 'Hysteria', 355056),
#  ('Dennis Chambers', 'Jazz', 'Outbreak', 659226),
#  ('Djavan', 'Latin', 'A Carta', 347297),
#  ('Dread Zeppelin', 'Rock', 'Your Time Is Gonna Come', 310774),
#  ('Ed Motta', 'Latin', 'Agora Que O Dia Acordou', 323213),
#  ('Edo de Waart & San Francisco Symphony', 'Classical', 'Two Fanfares for Orchestra: II. Short Ride in a Fast Machine', 254930),
#  ('Elis Regina', 'Latin', 'Aprendendo A Jogar', 290664),
#  ('Emanuel Ax, Eugene Ormandy & Philadelphia Orchestra', 'Classical', 'Concerto for Piano No. 2 in F Minor, Op. 21: II. Larghetto', 560342),
#  ('Emerson String Quartet', 'Classical', 'String Quartet No. 12 in C Minor, D. 703 "Quartettsatz": II. Andante - Allegro assai', 139200),
#  ('English Concert & Trevor Pinnock', 'Classical', 'Canon and Gigue in D Major: I. Canon', 271788),
#  ('Equale Brass Ensemble, John Eliot Gardiner & Munich Monteverdi Orchestra and Choir', 'Classical', 'Music for the Funeral of Queen Mary: VI. "Thou Knowest, Lord, the Secrets of Our Hearts"', 142081),
#  ('Eric Clapton', 'Blues', 'Old Love', 472920),
#  ('Eric Clapton', 'Latin', 'A Novidade', 324780),
#  ('Eugene Ormandy', 'Classical', 'On the Beautiful Blue Danube', 526696),
#  ('Faith No More', 'Alternative & Punk', 'The Real Thing', 493635),
#  ('Faith No More', 'Rock', 'King For A Day', 395859),
#  ('Falamansa', 'Latin', 'Avisa', 355030),
#  ('Felix Schmidt, London Symphony Orchestra & Rafael Frühbeck de Burgos', 'Classical', 'Concerto for Cello and Orchestra in E minor, Op. 85: I. Adagio - Moderato', 483133),
#  ('Foo Fighters', 'Alternative & Punk', 'Come Back', 469968),
#  ('Foo Fighters', 'Rock', 'End Over End', 352078),
#  ('Frank Sinatra', 'Easy Listening', 'Mack The Knife', 292075),
#  ('Frank Zappa & Captain Beefheart', 'Rock', 'Advance Romance', 677694),
#  ('Fretwork', 'Classical', 'Pavan, Lachrimae Antiquae', 253281),
#  ('Funk Como Le Gusta', 'Latin', 'Whistle Stop', 526132),
#  ('Gene Krupa', 'Jazz', 'Blue Rythm Fantasy', 348212),
#  ('Gerald Moore', 'Classical', 'Erlkonig, D.328', 261849),
#  ('Gilberto Gil', 'Jazz', 'Doce De Carnaval (Candy All)', 356101),
#  ('Gilberto Gil', 'Latin', 'Quanta (Live)', 357485),
#  ('Gilberto Gil', 'Soundtrack', 'A Volta Da Asa Branca', 271020),
#  ('Godsmack', 'Metal', 'Serenity', 274834),
#  ('Gonzaguinha', 'Latin', 'O Que É O Que É ?', 259291),
#  ('Green Day', 'Alternative & Punk', "Homecoming / The Death Of St. Jimmy / East 12th St. / Nobody Likes You / Rock And Roll Girlfriend / We're Coming Home Again", 558602),
#  ("Guns N' Roses", 'Metal', 'Estranged', 563800),
#  ("Guns N' Roses", 'Rock', 'Coma', 616511),
#  ('Gustav Mahler', 'Classical', 'Das Lied Von Der Erde, Von Der Jugend', 223583),
#  ('Göteborgs Symfoniker & Neeme Järvi', 'Classical', 'Symphony No. 2, Op. 16 -  "The Four Temperaments": II. Allegro Comodo e Flemmatico', 286998),
#  ('Habib Koité and Bamada', 'World', 'I Ka Barra (Your Work)', 300605),
#  ('Herbert Von Karajan, Mirella Freni & Wiener Philharmoniker', 'Classical', 'Madama Butterfly: Un Bel Dì Vedremo', 277639),
#  ('Heroes', 'Drama', 'How to Stop an Exploding Man', 2687103),
#  ('Heroes', 'TV Shows', 'Genesis', 2611986),
#  ('Hilary Hahn, Jeffrey Kahane, Los Angeles Chamber Orchestra & Margaret Batjer', 'Classical', 'Concerto for 2 Violins in D Minor, BWV 1043: I. Vivace', 193722),
#  ('House Of Pain', 'Hip Hop/Rap', 'Feel It', 239908),
#  ('Incognito', 'Jazz', 'She Wears Black', 528666),
#  ('Iron Maiden', 'Blues', '05 - Phantom of the Opera', 428016),
#  ('Iron Maiden', 'Heavy Metal', 'Dance Of Death', 516649),
#  ('Iron Maiden', 'Metal', 'Rime of the Ancient Mariner', 816509),
#  ('Iron Maiden', 'Rock', 'Sign Of The Cross', 678008),
#  ('Itzhak Perlman', 'Classical', '24 Caprices, Op. 1, No. 24, for Solo Violin, in A Minor', 265541),
#  ('JET', 'Alternative & Punk', 'Lazy Gun', 282174),
#  ('James Brown', 'R&B/Soul', "I'm Real", 334236),
#  ('James Levine', 'Classical', 'Cavalleria Rusticana \\ Act \\ Intermezzo Sinfonico', 243436),
#  ('Jamiroquai', 'Electronica/Dance', 'Just Another Story', 529684),
#  ('Jamiroquai', 'R&B/Soul', 'Black Capricorn Day', 341629),
#  ('Jamiroquai', 'Rock', 'Revolution 1993', 616829),
#  ('Jimi Hendrix', 'Rock', 'Third Stone From The Sun', 404453),
#  ('Joe Satriani', 'Rock', 'Echo', 337570),
#  ('Jorge Ben', 'Latin', 'País Tropical', 452519),
#  ('Jota Quest', 'Latin', 'Onibusfobia', 315977),
#  ('João Suplicy', 'World', 'Pura Elegancia', 284107),
#  ('Judas Priest', 'Metal', 'Victim Of Change (Live)', 430942),
#  ('Julian Bream', 'Classical', 'Partita in E Major, BWV 1006A: I. Prelude', 285673),
#  ('Karsh Kale', 'Electronica/Dance', 'One Step Beyond', 366085),
#  ("Kent Nagano and Orchestre de l'Opéra de Lyon", 'Classical', 'Symphony No. 2: III. Allegro vivace', 376510),
#  ('Kiss', 'Rock', 'I Still Love You', 369815),
#  ('Led Zeppelin', 'Rock', 'Dazed And Confused', 1612329),
#  ('Legião Urbana', 'Latin', 'Faroeste Caboclo', 543007),
#  ('Lenny Kravitz', 'Metal', 'Still Of The Night', 398210),
#  ('Lenny Kravitz', 'Reggae', 'Equal Rights Downpresser Man', 366733),
#  ('Lenny Kravitz', 'Rock', 'Let Love Rule', 342648),
#  ('Leonard Bernstein & New York Philharmonic', 'Classical', 'Adagio for Strings from the String Quartet, Op. 11', 596519),
#  ('Les Arts Florissants & William Christie', 'Classical', 'Concert pour 4 Parties de V**les, H. 545: I. Prelude', 110266),
#  ('London Symphony Orchestra & Sir Charles Mackerras', 'Classical', 'The Nutcracker, Op. 71a, Act II: Scene 14: Pas de deux: Dance of the Prince & the Sugar-Plum Fairy', 304226),
#  ('Lost', 'Drama', 'Through a Looking Glass', 5088838),
#  ('Lost', 'TV Shows', 'Dave', 2825166),
#  ('Luciana Souza/Romero Lubambo', 'Latin', 'Muita Bobeira', 172710),
#  ('Luciano Pavarotti', 'Classical', 'Turandot, Act III, Nessun dorma!', 176911),
#  ('Lulu Santos', 'Latin', 'Fullgás', 346070),
#  ('Marcos Valle', 'Latin', 'Samba da Bençaco', 282200),
#  ('Marillion', 'Rock', 'Blind Curve: Vocal Under A Bloodlight / Passing Strangers / Mylo / Perimeter Walk / Threshold', 569704),
#  ('Marisa Monte', 'Latin', 'O Xote Das Meninas', 291866),
#  ('Martin Roscoe', 'Classical', 'Metopes, Op. 29: Calypso', 333669),
#  ('Marvin Gaye', 'R&B/Soul', 'Ego Tripping Out', 314514),
#  ('Maurizio Pollini', 'Classical', 'Piano Sonata No. 14 in C Sharp Minor, Op. 27, No. 2, "Moonlight": I. Adagio sostenuto', 391000),
#  ('Mela Tenenbaum, Pro Musica Prague & Richard Kapp', 'Classical', 'Concerto for Violin, Strings and Continuo in G Major, Op. 3, No. 9: I. Allegro', 493573),
#  ('Men At Work', 'Rock', 'Down by the Sea', 408163),
#  ('Metallica', 'Metal', 'Mercyful Fate', 671712),
#  ('Michael Tilson Thomas & San Francisco Symphony', 'Classical', "Symphonie Fantastique, Op. 14: V. Songe d'une nuit du sabbat", 561967),
#  ('Michele Campanella', 'Classical', 'Étude 1, In C Major - Preludio (Presto) - Liszt', 51780),
#  ('Miles Davis', 'Jazz', 'My Funny Valentine (Live)', 907520),
#  ('Milton Nascimento', 'Latin', 'Norwegian Wood', 413910),
#  ('Motörhead', 'Metal', 'The Chase Is Better Than The Catch', 258403),
#  ('Mônica Marianno', 'World', 'A Moça e a Chuva', 274625),
#  ('Mötley Crüe', 'Metal', 'Glitter', 340114),
#  ('Nash Ensemble', 'Classical', 'Quintet for Horn, Violin, 2 Violas, and Cello in E Flat Major, K. 407/386c: III. Allegro', 221331),
#  ('Nicolaus Esterhazy Sinfonia', 'Classical', 'Symphony No. 3 in E-flat major, Op. 55, "Eroica" - Scherzo: Allegro Vivace', 356426),
#  ('Nirvana', 'Rock', 'Smells Like Teen Spirit', 301296),
#  ('O Rappa', 'Electronica/Dance', 'Prostituta', 359000),
#  ('O Terço', 'Rock', 'Às Vezes', 330292),
#  ('Olodum', 'Latin', 'Madagáscar Olodum', 252264),
#  ('Orchestra of The Age of Enlightenment', 'Classical', 'Concerto No.2 in F Major, BWV1047, I. Allegro', 307244),
#  ('Orchestre Révolutionnaire et Romantique & John Eliot Gardiner', 'Classical', 'Symphony No.5 in C Minor: I. Allegro con brio', 392462),
#  ('Os Mutantes', 'Alternative & Punk', 'A E O Z', 518556),
#  ('Os Paralamas Do Sucesso', 'Latin', 'Será Que Vai Chover?', 337057),
#  ('Otto Klemperer & Philharmonia Orchestra', 'Classical', 'Prometheus Overture, Op. 43', 339567),
#  ('Ozzy Osbourne', 'Metal', 'Steal Away (The Night)', 485720),
#  ('Ozzy Osbourne', 'Rock', 'Iron Man/Children of the Grave', 552308),
#  ('Page & Plant', 'Rock', 'Blue Train', 405028),
#  ('Passengers', 'Soundtrack', 'Always Forever Now', 383764),
#  ("Paul D'Ianno", 'Rock', 'Phantom Of The Opera', 418168),
#  ('Pearl Jam', 'Alternative & Punk', 'Inside Job', 428643),
#  ('Pearl Jam', 'Rock', 'Release', 546063),
#  ('Philharmonia Orchestra & Sir Neville Marriner', 'Classical', "A Midsummer Night's Dream, Op.61 Incidental Music: No.7 Notturno", 387826),
#  ('Philip Glass Ensemble', 'Soundtrack', 'Koyaanisqatsi', 206005),
#  ('Pink Floyd', 'Rock', 'Us And Them', 461035),
#  ('Planet Hemp', 'Hip Hop/Rap', 'Se Liga', 410409),
#  ('Queen', 'Rock', 'Innuendo', 387761),
#  ('R.E.M.', 'Alternative & Punk', 'I Remember California', 304013),
#  ('R.E.M.', 'Rock', 'Leave', 437968),
#  ('R.E.M. Feat. Kate Pearson', 'Alternative & Punk', 'Low', 296777),
#  ('Raimundos', 'Alternative & Punk', 'Esporrei Na Manivela', 293276),
#  ('Raul Seixas', 'Rock', 'Muita Estrela, Pouca Constelação', 268068),
#  ('Red Hot Chili Peppers', 'Alternative & Punk', 'Sir Psycho Sexy', 496692),
#  ('Red Hot Chili Peppers', 'Rock', 'Venice Queen', 369110),
#  ('Richard Marlow & The Choir of Trinity College, Cambridge', 'Classical', 'Miserere mei, Deus', 501503),
#  ('Roger Norrington, London Classical Players', 'Classical', 'Act IV, Symphony', 364296),
#  ('Royal Philharmonic Orchestra & Sir Thomas Beecham', 'Classical', 'Symphony No. 104 in D Major "London": IV. Finale: Spiritoso', 306687),
#  ('Rush', 'Rock', 'Xanadu', 667428),
#  ('Santana', 'Rock', "We've Got To Get Together/Jingo", 1070027),
#  ('Scholars Baroque Ensemble', 'Classical', 'The Messiah: Behold, I Tell You a Mystery... The Trumpet Shall Sound', 582029),
#  ('Scorpions', 'Rock', 'Still Loving You', 390674),
#  ('Sergei Prokofiev & Yuri Temirkanov', 'Classical', 'Symphony No.1 in D Major, Op.25 "Classical", Allegro Con Brio', 254001),
#  ('Sir Georg Solti & Wiener Philharmoniker', 'Classical', 'Die Walküre: The Ride of the Valkyries', 189008),
#  ('Sir Georg Solti, Sumi Jo & Wiener Philharmoniker', 'Opera', 'Die Zauberflöte, K.620: "Der Hölle Rache Kocht in Meinem Herze"', 174813),
#  ('Skank', 'Rock', 'Poconé', 318406),
#  ('Smashing Pumpkins', 'Alternative & Punk', 'Aeroplane Flies High', 473391),
#  ('Soundgarden', 'Rock', 'Hands All Over', 362475),
#  ('Spyro Gyra', 'Jazz', 'Heliopolis', 338729),
#  ('Stevie Ray Vaughan & Double Trouble', 'Blues', 'Riviera Paradise', 528692),
#  ('Stone Temple Pilots', 'Rock', 'Where The River Goes', 505991),
#  ('System Of A Down', 'Metal', 'Lost in Hollywood', 320783),
#  ('Temple of the Dog', 'Alternative', 'Reach Down', 672773),
#  ('Terry Bozzio, Tony Levin & Steve Stevens', 'Rock', 'The Sun Road', 880640),
#  ('The 12 Cellists of The Berlin Philharmonic', 'Classical', 'Adios nonino', 289388),
#  ('The Black Crowes', 'Blues', 'Title Song', 505521),
#  ('The Clash', 'Alternative & Punk', 'The Call Up', 324336),
#  ('The Cult', 'Rock', 'Sun King', 368431),
#  ('The Doors', 'Rock', 'The End', 701831),
#  ("The King's Singers", 'Classical', 'Sing Joyfully', 133768),
#  ('The Office', 'Comedy', 'The Job', 2541875),
#  ('The Office', 'TV Shows', 'Branch Closing', 1822781),
#  ('The Police', 'Rock', 'Wrapped Around Your Finger', 315454),
#  ('The Posies', 'Rock', "I Guess You're Right", 212044),
#  ('The Rolling Stones', 'Rock', 'Out Of Control', 479242),
#  ('The Tea Party', 'Alternative & Punk', 'Save Me (Remix)', 396303),
#  ('The Who', 'Rock', "Won't Get Fooled Again (Full Length Version)", 513750),
#  ('Tim Maia', 'Latin', 'O Descobridor Dos Sete Mares', 262974),
#  ('Titãs', 'Alternative & Punk', 'Comida', 322612),
#  ('Ton Koopman', 'Classical', 'Toccata and Fugue in D Minor, BWV 565: I. Toccata', 153901),
#  ('Toquinho & Vinícius', 'Bossa Nova', 'Samba Da Bênção', 409965),
#  ('U2', 'Pop', 'Mother', 287740),
#  ('U2', 'Rock', 'All I Want Is You', 591986),
#  ('UB40', 'Reggae', 'Bring Me Your Cup', 341498),
#  ('Van Halen', 'Rock', 'Year to the Day', 514612),
#  ('Various Artists', 'Latin', 'Caprichosos', 351320),
#  ('Various Artists', 'Pop', 'Daniela', 230791),
#  ('Various Artists', 'Soundtrack', 'Sao Lucas 2001', 296254),
#  ('Velvet Revolver', 'Rock', 'Loving The Alien', 348786),
#  ('Vinícius De Moraes', 'Latin', 'A Bencao E Outros', 421093),
#  ('Wilhelm Kempff', 'Classical', 'Aria Mit 30 Veränderungen, BWV 988 "Goldberg Variations": Aria', 120463),
#  ('Yehudi Menuhin', 'Classical', 'Sonata for Solo Violin: IV: Presto', 299350),
#  ('Yo-Yo Ma', 'Classical', 'Suite for Solo Cello No. 1 in G Major, BWV 1007: I. Prélude', 143288),
#  ('Zeca Pagodinho', 'Latin', 'Verdade', 332826)]

# %% [markdown]
# ## Задание 2
# Посчитать скользящее среднее выручки по годам.

# %%
# %%sql
# SELECT
#     SUBSTR(i.InvoiceDate, 1, 4) AS Year,
#     SUM(ii.Quantity * t.UnitPrice) AS Revenue,
#     AVG(SUM(ii.Quantity * t.UnitPrice)) OVER (ORDER BY SUBSTR(i.InvoiceDate, 1, 4) ROWS BETWEEN 2 PRECEDING AND CURRENT ROW) AS MovingAverage
# FROM Invoices i
# JOIN invoice_items ii ON i.InvoiceId = ii.InvoiceId
# JOIN tracks t ON ii.TrackId = t.TrackId
# GROUP BY Year
# HAVING Revenue IS NOT NULL
# ORDER BY Year;
# Out:
#  * sqlite:///store.db
# Done.
# [('2023', 3205.7899999999304, 3205.7899999999304),
#  ('2024', 1583.190000000008, 2394.4899999999693)]

# %% [markdown]
# ## Задание 3
#
# Для каждого плейлиста вывести трек с наибольшей продолжительностью, трек с наименьшей стоимостью (если у треков одинаковая стоимость, то вывести тот, который весит меньше всех), и жанр данного плейлиста (жанром плейлиста будет называться тот жанр, треков которого больше всех в плейлисте).

# %%
# %%sql
# WITH PlaylistTracks AS (
#     SELECT
#         p.PlaylistId,
#         t.Name AS TrackName,
#         t.Milliseconds,
#         t.UnitPrice,
#         g.Name AS Genre,
#         ROW_NUMBER() OVER (PARTITION BY p.PlaylistId ORDER BY t.Milliseconds DESC) AS LongestTrackRank,
#         ROW_NUMBER() OVER (PARTITION BY p.PlaylistId ORDER BY t.UnitPrice, t.Milliseconds ASC) AS CheapestTrackRank,
#         COUNT(t.GenreId) OVER (PARTITION BY p.PlaylistId, t.GenreId) AS GenreCount
#     FROM playlists p
#     JOIN playlist_track pt ON p.PlaylistId = pt.PlaylistId
#     JOIN tracks t ON pt.TrackId = t.TrackId
#     JOIN genres g ON t.GenreId = g.GenreId
# )
#
# SELECT
#     pt.PlaylistId,
#     MAX(CASE WHEN LongestTrackRank = 1 THEN TrackName END) AS LongestTrack,
#     MAX(CASE WHEN CheapestTrackRank = 1 THEN TrackName END) AS CheapestTrack,
#     (SELECT g.Name
#      FROM genres g
#      WHERE g.Name IN (
#          SELECT g2.Name
#          FROM PlaylistTracks pt2
#          JOIN genres g2 ON pt2.Genre = g2.Name
#          WHERE pt2.PlaylistId = pt.PlaylistId
#          GROUP BY g2.Name
#          ORDER BY COUNT(*) DESC
#          LIMIT 1)
#     ) AS DominantGenre
# FROM PlaylistTracks pt
# GROUP BY pt.PlaylistId
# ORDER BY pt.PlaylistId;
# Out:
#  * sqlite:///store.db
# Done.
# [(3, 'Occupation / Precipice', 'Your Time Is Gonna Come', 'TV Shows'),
#  (4, 'Advance Romance', 'Oh, My Love', 'Rock'),
#  (5, 'Coma', 'My World', 'Rock'),
#  (10, 'Occupation / Precipice', 'Greatest Hits', 'TV Shows'),
#  (11, 'Vai Passar', 'A Banda', 'Latin'),
#  (13, 'Symphony No. 3 Op. 36 for Orchestra and Soprano "Symfonia Piesni Zalosnych" \\ Lento E Largo - Tranquillissimo', 'Étude 1, In C Major - Preludio (Presto) - Liszt', 'Classical'),
#  (15, 'Adagio for Strings from the String Quartet, Op. 11', 'Aria Mit 30 Veränderungen, BWV 988 "Goldberg Variations": Aria', 'Classical'),
#  (16, 'Alive', 'American Idiot', 'Rock'),
#  (17, 'Master Of Puppets', 'Run to the Hills', 'Metal')]

# %% [markdown]
# ## Задание 4
#
# Для каждого жанра вывести треки, которые встречались в большем числе заказов,
# сумму, потраченную на данные треки, количество купленных треков и компанию, которая больше всех приобрела данную композицию.

# %%
# %%sql
# WITH TrackOrders AS (
#     SELECT
#         t.TrackId,
#         t.Name AS TrackName,
#         g.Name AS Genre,
#         c.Company,
#         COUNT(i.InvoiceId) AS OrderCount,
#         SUM(ii.Quantity) AS TotalQuantity,
#         SUM(t.UnitPrice * ii.Quantity) AS TotalSpent
#     FROM tracks t
#     JOIN genres g ON t.GenreId = g.GenreId
#     JOIN invoice_items ii ON t.TrackId = ii.TrackId
#     JOIN invoices i ON ii.InvoiceId = i.InvoiceId
#     JOIN customers c ON i.CustomerId = c.CustomerId
#     GROUP BY t.TrackId, c.Company
# ),
#
# RankedTracks AS (
#     SELECT
#         TrackName,
#         Genre,
#         TotalSpent,
#         TotalQuantity,
#         OrderCount,
#         Company,
#         ROW_NUMBER() OVER (PARTITION BY Genre ORDER BY OrderCount DESC) AS Rank
#     FROM TrackOrders
# )
#
# SELECT Genre, TrackName, TotalSpent, TotalQuantity, Company
# FROM RankedTracks
# WHERE Rank = 1 AND Company IS NOT NULL
# ORDER BY Genre;
# Out:
#  * sqlite:///store.db
# Done.
# [('Alternative', 'Say Hello 2 Heaven', 1.98, 2, 'Oracle'),
#  ('Blues', 'First Time I Met The Blues', 0.99, 1, 'BMW'),
#  ('Comedy', 'The Convict', 1.99, 1, 'Oracle'),
#  ('Easy Listening', 'New York, New York', 2.49, 1, 'Microsoft Corporation'),
#  ('Electronica/Dance', 'Light Years', 0.99, 1, 'JetBrains s.r.o.'),
#  ('Heavy Metal', 'Wildest Dreams', 0.99, 1, 'Google Inc.'),
#  ('Rock And Roll', 'Money', 1.99, 1, 'Google Inc.'),
#  ('Sci Fi & Fantasy', 'Crossroads, Pt. 1', 1.99, 1, 'Intel')]

# %% [markdown]
# ## Задание 5
# Составить рейтинг клиентов по количеству потраченных ими денег.

# %%
# %%sql
# WITH CustomerSpending AS (
#     SELECT
#         c.CustomerId,
#         c.FirstName || ' ' || c.LastName AS CustomerName,
#         SUM(ii.Quantity * t.UnitPrice) AS TotalSpent
#     FROM customers c
#     JOIN invoices i ON c.CustomerId = i.CustomerId
#     JOIN invoice_items ii ON i.InvoiceId = ii.InvoiceId
#     JOIN tracks t ON t.TrackId = ii.TrackId
#     WHERE Company IS NOT NULL
#     GROUP BY c.CustomerId
# )
# SELECT
#     CustomerId,
#     CustomerName,
#     TotalSpent,
#     RANK() OVER (ORDER BY TotalSpent DESC) AS SpendingRank
# FROM CustomerSpending
# ORDER BY SpendingRank;
# Out:
#  * sqlite:///store.db
# Done.
# [(38, 'Niklas Schröder', 116.28999999999992, 1),
#  (2, 'Leonie Köhler', 108.33999999999993, 2),
#  (23, 'John Gordon', 105.82999999999997, 3),
#  (37, 'Fynn Zimmermann', 102.86999999999995, 4),
#  (59, 'Puja Srivastava', 100.87999999999992, 5),
#  (19, 'Tim Goyer', 97.80999999999993, 6),
#  (17, 'Jack Smith', 91.41999999999999, 7),
#  (21, 'Kathy Chase', 90.38999999999993, 8),
#  (58, 'Manoj Pareek', 88.8499999999999, 9),
#  (12, 'Roberto Almeida', 87.38999999999992, 10),
#  (20, 'Dan Miller', 81.47999999999992, 11),
#  (26, 'Richard Cunningham', 79.51999999999997, 12),
#  (6, 'Helena Holý', 79.47999999999999, 13),
#  (36, 'Hannah Schneider', 78.41999999999996, 14),
#  (24, 'Frank Ralston', 77.96999999999996, 15),
#  (15, 'Jennifer Peterson', 77.41999999999994, 16),
#  (18, 'Michelle Brooks', 76.49999999999999, 17),
#  (22, 'Heather Leacock', 75.99, 18),
#  (25, 'Victor Stevens', 75.44999999999995, 19),
#  (48, 'Johannes Van der Berg', 74.95999999999997, 20),
#  (11, 'Alexandre Rocha', 72.38999999999999, 21),
#  (5, 'František Wichterlová', 71.44999999999999, 22),
#  (14, 'Mark Philips', 70.94, 23),
#  (27, 'Patrick Gray', 63.44000000000003, 24),
#  (28, 'Julia Barnett', 63.01000000000003, 25),
#  (10, 'Eduardo Martins', 60.980000000000025, 26),
#  (16, 'Frank Harris', 59.51000000000002, 27)]
